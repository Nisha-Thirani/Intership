# %%
# !pip install selenium

# %%
# !pip install webdriver_manager

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia. Url =
# https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome()
# Out:
# Error getting version of chromedriver 115. Retrying with chromedriver 114 (attempt 1/5)

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
driver.maximize_window()

# %%
Rank=[]
Name=[]
Artist=[]
Upload_Date=[]
Views=[]

rank=driver.find_elements(By.XPATH, '//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')
for i in rank[:30]:
    Rank.append(i.text)
    
name=driver.find_elements(By.XPATH, '//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
for i in name[:30]:
    Name.append(i.text[:-4])

    
artist=driver.find_elements(By.XPATH, '//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
for i in artist[:30]:
    Artist.append(i.text)
    
date=driver.find_elements(By.XPATH, '//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')
for i in date[:30]:
    Upload_Date.append(i.text)
    
views=driver.find_elements(By.XPATH, '//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
for i in views[:30]:
    Views.append(i.text)

# %%
df=pd.DataFrame({"Rank":Rank, "Name":Name, "Artist":Artist, "Upload Date":Upload_Date, "Views(Billions)":Views})
df
# Out:
#    Rank                                         Name  \
# 0    1.                            "Baby Shark Dance
# 1    2.                                   "Despacito
# 2    3.                       "Johny Johny Yes Papa"
# 3    4.                                  "Bath Song"
# 4    5.                               "Shape of You"
# 5    6.                              "See You Again"
# 6    8.                          "Wheels on the Bus"
# 7    7.                "Phonics Song with Two Words"
# 8    9.                                "Uptown Funk"
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"
# 10  11.                              "Gangnam Style"
# 11  12.   "Masha and the Bear – Recipe for Disaster"
# 12  13.                             "Dame Tu Cosita"
# 13  14.                                     "Axel F"
# 14  15.                                      "Sugar"
# 15  16.                                       "Roar"
# 16  17.                             "Counting Stars"
# ...

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1 ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
import selenium
import pandas as pd
import warnings 
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome()

# %%
driver.maximize_window()

# %%
driver.get("https://www.bcci.tv/")

# %%
menu=driver.find_element(By.XPATH, "/html/body/nav/div[1]/button")
menu.click()

# %%
international=driver.find_element(By.XPATH, '/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international.click()

# %%
for i in range(3):
    if i==38: break

title=[]
series=[]
stadium=[]
city=[]
place=[]
date=[]
time=[]

Title=driver.find_elements(By.XPATH, '//span[@class="matchOrderText ng-binding ng-scope"]')
for i in Title:
    title.append(i.text)
    
Series=driver.find_elements(By.XPATH, '//h5[@class="match-tournament-name ng-binding"]')
for i in Series:
    series.append(i.text)

try:
    Stadium=driver.find_elements(By.XPATH, '//span[@class="ng-binding ng-scope"]')
    for i in Stadium:
        stadium.append(i.text)
except:
    stadium.append('-')
    
    
City=driver.find_elements(By.XPATH, '//span[@class="ng-binding"]')
for i in City:
    city.append(i.text)
    
Date=driver.find_elements(By.XPATH, '//div[@class="match-dates ng-binding"]')
for i in Date:
    date.append(i.text)
    
Time=driver.find_elements(By.XPATH, '//div[@class="match-time no-margin ng-binding"]')
for i in Time:
    time.append(i.text)

# %%
print(len(title)), len(series), len(city), len(date), len(time)
# Out:
# 38
# (None, 38, 38, 38, 38)

# %%
df=pd.DataFrame({"Title":title, "Series":series, "Place":city, "Date":date, "Time":time})
df
# Out:
#          Title                              Series               Place  \
# 0   1st T20I -          INDIA TOUR OF IRELAND 2023              Dublin
# 1   2nd T20I -          INDIA TOUR OF IRELAND 2023              Dublin
# 2   3rd T20I -          INDIA TOUR OF IRELAND 2023              Dublin
# 3    1st ODI -                       ASIA CUP 2023           Pallekele
# 4    2nd ODI -                       ASIA CUP 2023           Pallekele
# 5    1st ODI -     AUSTRALIA TOUR OF INDIA 2023-24              Mohali
# 6    2nd ODI -     AUSTRALIA TOUR OF INDIA 2023-24              Indore
# 7    3rd ODI -     AUSTRALIA TOUR OF INDIA 2023-24              Rajkot
# 8    1st ODI -             ICC MENS WORLD CUP 2023             Chennai
# 9    2nd ODI -             ICC MENS WORLD CUP 2023               Delhi
# 10   3rd ODI -             ICC MENS WORLD CUP 2023           Ahmedabad
# 11   4th ODI -             ICC MENS WORLD CUP 2023                Pune
# ...

# %% [markdown]
# 3. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details: A)
# Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver=webdriver.Chrome()

# %%
driver.maximize_window()

# %%
driver.get('http://statisticstimes.com/')

# %%
economy=driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/button/i')
economy.click()

# %%
india=driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
india.click()

# %%
GDP=driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
GDP.click()

# %%
rank=[]
state=[]
GSDP1=[]
GSDP2=[]
share=[]
GDP=[]

Rank=driver.find_elements(By.XPATH, '//td[@class="data1"]')
for i in Rank[:33]:
    rank.append(i.text)
    
State=driver.find_elements(By.XPATH, '//td[@class="name"]')
for i in State[:33]:
    state.append(i.text)
    
try:
    gsdp=driver.find_elements(By.XPATH, '//div[@class="dataTables_wrapper"]/table/tbody/tr/td[3]')
    for i in gsdp[:33]:
        GSDP1.append(i.text)
except:
    GSDP1.append('-')
    

try:
    gsdp1=driver.find_elements(By.XPATH, '//td[@class="data sorting_1"]')
    for i in gsdp1[:33]:
        GSDP2.append(i.text)
except:
    GSDP2.append('-')
    

Share=driver.find_elements(By.XPATH, '//div[@class="dataTables_wrapper"]/table/tbody/tr/td[5]')
for i in Share[:33]:
    share.append(i.text)
    
gdp=driver.find_elements(By.XPATH, '//div[@class="dataTables_wrapper"]/table/tbody/tr/td[6]')
for i in gdp[:33]:
    GDP.append(i.text)

# %%
print(len(rank)), len(state), len(GSDP1), len(GSDP2), len(share), len(GDP)
# Out:
# 33
# (None, 33, 33, 33, 33, 33)

# %%
df=pd.DataFrame({"Rank":rank, "State":state, "GSDP(2018-19)current price":GSDP1, 'GSDP(2019-20)current price':GSDP2, "Share":share, "GDP":GDP})
df
# Out:
#    Rank                      State GSDP(2018-19)current price  \
# 0     1                Maharashtra                          -
# 1     2                 Tamil Nadu                  1,845,853
# 2     3              Uttar Pradesh                  1,687,818
# 3     4                    Gujarat                          -
# 4     5                  Karnataka                  1,631,977
# 5     6                West Bengal                  1,253,832
# 6     7                  Rajasthan                  1,020,989
# 7     8             Andhra Pradesh                    972,782
# 8     9                  Telangana                    969,604
# 9    10             Madhya Pradesh                    906,672
# 10   11                     Kerala                          -
# 11   12                      Delhi                    856,112
# 12   13                    Haryana                    831,610
# 13   14                      Bihar                    611,804
# ...

# %% [markdown]
# Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import ElementNotInteractableException

# %%
driver=webdriver.Chrome()

# %%
driver.maximize_window()

# %%
driver.get('https://github.com/')

# %%
try:
    explore_click = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
    explore_click.click()
    trend_click = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a")
    trend_click.click()

except ElementNotInteractableException:
    explore_click = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
    explore_click.click()
    trend_click = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a")
    trend_click.click()

# %%
title=[]
description=[]
count=[]
language=[]

Title=driver.find_elements(By.XPATH, '//a[@class="Link"]')
for i in Title:
    title.append(i.text)
    
try:
    desc=driver.find_elements(By.XPATH, '//p[@class="col-9 color-fg-muted my-1 pr-4"]' )
    for i in desc:
        description.append(i.text)
except NoSuchElementException:
    description.append("NaN")
    
Count=driver.find_elements(By.XPATH, '//a[@class="Link Link--muted d-inline-block mr-3"]')
for i in Count[1:49:2]:
    count.append(i.text)
    
try:
    Language=driver.find_elements(By.XPATH, '//span[@class="d-inline-block ml-0 mr-3"]/span[2]')
    for i in Language:
        language.append(i.text)
except:
    language.append("NaN")

# %%
print(len(title)), len(description), len(count), len(language)
# Out:
# 24
# (None, 23, 24, 22)

# %%
df=pd.DataFrame({"Title":title[:22], "Description":description[:22], "Contribution Count":count[:22], "Language":language[:22]})
df
# Out:
#                                        Title  \
# 0                       lllyasviel / Fooocus
# 1                     imartinez / privateGPT
# 2                phoboslab / wipeout-rewrite
# 3                      NVlabs / neuralangelo
# 4                        Z4nzu / hackingtool
# 5                            yt-dlp / yt-dlp
# 6    awesome-selfhosted / awesome-selfhosted
# 7       graphdeco-inria / gaussian-splatting
# 8                        immich-app / immich
# 9                 lyswhut / lx-music-desktop
# 10       binhnguyennus / awesome-scalability
# 11      joonspk-research / generative_agents
# 12  iam-veeramalla / aws-devops-zero-to-hero
# 13       poteto / hiring-without-whiteboards
# 14                    modelscope / facechain
# 15                          mlc-ai / mlc-llm
# 16                     ytdl-org / youtube-dl
# 17                          libsdl-org / SDL
# 18           bregman-arie / devops-exercises
# 19                         bitcoin / bitcoin
# ...

# %% [markdown]
# Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome()

# %%
driver.maximize_window()

# %%
driver.get('http://www.billboard.com/')

# %%
menu=driver.find_element(By.XPATH, '/html/body/div[3]/div[9]/div/div/div/ul/li[1]/h3/button/span')
menu.click()

# %%
hot=driver.find_element(By.XPATH, '/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a')
hot.click()

# %%
name=[]
artist=[]
lwr=[]
pr=[]
weekonboard=[]

Name=driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/h3')
for i in Name:
    name.append(i.text)
    
Artist=driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/span')
for i in Artist[0:400:4]:
    artist.append(i.text)
    
LWR=driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/span')
for i in LWR[1:400:4]:
    lwr.append(i.text)
    
PR=driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/span')
for i in PR[2:400:4]:
    pr.append(i.text)
    
Time=driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/span')
for i in Time[3:400:4]:
    weekonboard.append(i.text)

# %%
print(len(name)), len(artist), len(lwr), len(pr), len(weekonboard)
# Out:
# 100
# (None, 100, 100, 100, 100)

# %%
df=pd.DataFrame({"Name":name, "Artist Name":artist, "Last Week Rank":lwr, "Peak Rank":pr, "Week on board":weekonboard})
df
# Out:
#                             Name                           Artist Name  \
# 0                     Last Night                         Morgan Wallen
# 1                       Fast Car                            Luke Combs
# 2                       Meltdown          Travis Scott Featuring Drake
# 3                   Cruel Summer                          Taylor Swift
# 4                           FE!N  Travis Scott Featuring Playboi Carti
# ..                           ...                                   ...
# 95                     Oh U Went            Young Thug Featuring Drake
# 96                           ICU                            Coco Jones
# 97                  Pound Town 2   Sexyy Red & Tay Keith & Nicki Minaj
# 98  Bzrp Music Sessions, Vol. 55                 Bizarrap & Peso Pluma
# 99                   Johnny Dang    That Mexican OT, Paul Wall & DRODi
#
#    Last Week Rank Peak Rank Week on board
# 0               2         1            27
# ...

# %% [markdown]
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey You have to find the following details:
# 6. Scrape the details of Highest selling novels.
# compare
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException

# %%
driver=webdriver.Chrome()

# %%
driver.maximize_window()

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
book=[]
author=[]
sold=[]
publisher=[]
genre=[]

Book=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in Book:
    book.append(i.text)
    
Author=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in Author:
    author.append(i.text)
    
Sold=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in Sold:
    sold.append(i.text)
    
Publisher=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in Publisher:
    publisher.append(i.text)
    
Genre=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in Genre:
    genre.append(i.text)

# %%
df=pd.DataFrame({"Book Name":book, "Author Name":author, "Volume Sales":sold, "Publisher":publisher, "Genre":genre})
df
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume Sales        Publisher                        Genre
# ...

# %% [markdown]
# 7. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/ You
# have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome()

# %%
driver.maximize_window()

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
name=[]
time=[]
genre=[]
run_time=[]
ratings=[]
votes=[]

Name=driver.find_elements(By.XPATH, '//h3[@class="lister-item-header"]/a')
for i in Name:
    name.append(i.text)
    
Time=driver.find_elements(By.XPATH, '//span[@class="lister-item-year text-muted unbold"]')
for i in Time:
    time.append(i.text)
    
Genre=driver.find_elements(By.XPATH, '//span[@class="genre"]')
for i in Genre:
    genre.append(i.text)
    
Run_time=driver.find_elements(By.XPATH, '//span[@class="runtime"]')
for i in Run_time:
    run_time.append(i.text)
    
Ratings=driver.find_elements(By.XPATH, '//span[@class="ipl-rating-star__rating"]')
for i in Ratings[0:2300:23]:
    ratings.append(i.text)
    
Votes=driver.find_elements(By.XPATH, '//span[@name="nv"]')
for i in Votes:
    votes.append(i.text)

# %%
print(len(name)), len(time), len(genre), len(run_time), len(ratings), len(votes)
# Out:
# 100
# (None, 100, 100, 100, 100, 100)

# %%
df=pd.DataFrame({"Movie Name":name, "Year span":time, "Genre":genre, "Run Time":run_time, "Ratings":ratings, "Votes":votes})
df
# Out:
#                         Movie Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2024)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,192,325
# ...

# %% [markdown]
# . Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome()
# Out:
# Error getting version of chromedriver 115. Retrying with chromedriver 114 (attempt 1/5)

# %%
driver.maximize_window()

# %%
driver.get('https://archive.ics.uci.edu/')

# %%
dataset=driver.find_element(By.XPATH, '/html/body/div/div[1]/div[1]/main/div/div[1]/div/div/div/a[1]')
dataset.click()

# %%
name=[]
Ds_type=[]
task=[]
attribute=[]
instance=[]
Noofa=[]
year=[]

start = 0
end = 64

for page in range(start, end):
    
    Name=driver.find_elements(By.XPATH, '//main[@class="min-h-screen"]/div/div/div/div/div/div/h2')
for i in Name[:634]:
    name.append(i.text)
    
ds_type=driver.find_elements(By.XPATH, '//main[@class="min-h-screen"]/div/div/div/div/div/div/div/div/span' )
for i in ds_type[1:40:4]:
    Ds_type.append(i.text)
    
Task=driver.find_elements(By.XPATH, '//main[@class="min-h-screen"]/div/div/div/div/div/div/div/div/span')
for i in Task[0:40:4]:
    task.append(i.text)
        
Instance=driver.find_elements(By.XPATH, '//main[@class="min-h-screen"]/div/div/div/div/div/div/div/div/span')
for i in Instance[2:40:4]:
    instance.append(i.text)
    
noof=driver.find_elements(By.XPATH, '//main[@class="min-h-screen"]/div/div/div/div/div/div/div/div/span')
for i in noof[3:40:4]:
    Noofa.append(i.text)
    
    
nextbutton=driver.find_element(By.XPATH, '/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
nextbutton.click()

# %%
print(len(name)), len(Ds_type), len(task), len(attribute), len(instance), len(Noofa), len(year)
# Out:
# 10
# (None, 10, 10, 0, 10, 10, 0)

# %%
df=pd.DataFrame({"Name":name, "Data Type":Ds_type, "Task":task, "Instances":instance, "No of Attributes":Noofa})
df
# Out:
#                                  Name                    Data Type  \
# 0                             Abalone                 Multivariate
# 1                       Breast Cancer                 Multivariate
# 2        Statlog (German Credit Data)                 Multivariate
# 3                Glass Identification                 Multivariate
# 4                        Wine Quality                 Multivariate
# 5                       Census Income                 Multivariate
# 6  Breast Cancer Wisconsin (Original)                 Multivariate
# 7                            Auto MPG                 Multivariate
# 8                          Automobile                 Multivariate
# 9                     Thyroid Disease  Multivariate, Domain-Theory
#
#                          Task         Instances No of Attributes
# 0              Classification   4.18K Instances     8 Attributes
# 1              Classification     286 Instances     9 Attributes
# ...
